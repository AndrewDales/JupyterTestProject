# %% [markdown]
# # Python Plotting with Matplotlib
# ## Examples from [Real Python - Matplotib Guide](https://realpython.com/python-matplotlib-guide)

# %%
# This figure shows the name of several matplotlib elements composing a figure

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
import pandas as pd

plt.rcdefaults()
plt.style.use({'figure.facecolor':'white'})


np.random.seed(19680801)

X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)


def minor_tick(x, pos):
    if not x % 1.0:
        return ""
    return f"{x}.2f"

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

ax.plot(X, Y1, c=(0.25, 0.25, 1.00), lw=2, label="Blue signal", zorder=10)
ax.plot(X, Y2, c=(1.00, 0.25, 0.25), lw=2, label="Red signal")
ax.plot(X, Y3, linewidth=0,
        marker='o', markerfacecolor='w', markeredgecolor='k')

ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")

ax.legend()


def circle(x, y, radius=0.15):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)


def text(x, y, text):
    ax.text(x, y, text, backgroundcolor="white",
            ha='center', va='top', weight='bold', color='blue')


# Minor tick
circle(0.50, -0.10)
text(0.50, -0.32, "Minor tick label")

# Major tick
circle(-0.03, 4.00)
text(0.03, 3.80, "Major tick")

# Minor tick
circle(0.00, 3.50)
text(0.00, 3.30, "Minor tick")

# Major tick label
circle(-0.15, 3.00)
text(-0.15, 2.80, "Major tick label")

# X Label
circle(1.80, -0.27)
text(1.80, -0.45, "X axis label")

# Y Label
circle(-0.27, 1.80)
text(-0.27, 1.6, "Y axis label")

# Title
circle(1.60, 4.13)
text(1.60, 3.93, "Title")

# Blue plot
circle(1.75, 2.80)
text(1.75, 2.60, "Line\n(line plot)")

# Red plot
circle(1.20, 0.60)
text(1.20, 0.40, "Line\n(line plot)")

# Scatter plot
circle(3.20, 1.75)
text(3.20, 1.55, "Markers\n(scatter plot)")

# Grid
circle(3.00, 3.00)
text(3.00, 2.80, "Grid")

# Legend
circle(3.70, 3.80)
text(3.70, 3.60, "Legend")

# Axes
circle(0.5, 0.5)
text(0.5, 0.3, "Axes")

# Figure
circle(-0.3, 0.65)
text(-0.3, 0.45, "Figure")

color = 'blue'
ax.annotate('Spines', xy=(4.0, 0.35), xycoords='data',
            xytext=(3.3, 0.5), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.annotate('', xy=(3.15, 0.0), xycoords='data',
            xytext=(3.45, 0.45), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.text(4.0, -0.4, "Made with http://matplotlib.org",
        fontsize=10, ha="right", color='.5')

plt.show()

# %%
plt.plot([1, 3, 2])
plt.title("A Random Graph")
plt.legend("A line")
plt.xlabel("The x-axis")
plt.ylabel("The y-axis")
# Out:
# Text(0, 0.5, 'The y-axis')

# %%
fig, ax = plt.subplots()
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, len(rng)))
yrs = 1950 +rng
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.grid(axis='both')
ax.set_title('Combined Widgets Over Time')
ax.legend(loc='upper left')
ax.set_ylabel('Total Widgets')
ax.set_xlabel('Year')
ax.set_xlim(xmin=yrs[0], xmax=yrs[-1])
fig.tight_layout()

# %%
x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)
data = np.column_stack((x,y))
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 9))
ax1.scatter(x=x,y=y , marker='*', c='r', edgecolor='b')
ax1.grid(axis='both')
ax1.set_title('Scatter: $x$ versus $y$')
ax1.set_xlabel('$x$')
ax1.set_ylabel('$y$')

# min_data = data.min()
# max_data = data.max()
# ax2.hist(data, bins=np.arange(min_data, max_data+2),
#          label=('x','y'),
#          edgecolor='dimgray')
# ax2.grid(axis='both')
# ax2.legend(loc='best')
# ax2.set_title('Frequencies of $x$ and $y$')
# ax2.set_ylabel('Frequency')
# ax2.yaxis.tick_right()
# ax2.set_xticks(np.arange(min_data, max_data+2))

x_labels, x_counts = np.unique(x, return_counts=True)
y_labels, y_counts = np.unique(y, return_counts=True)
width = 0.35
ax2.bar(x_labels - width/2, x_counts, width, align='center', label='x')
ax2.bar(y_labels + width/2, y_counts, width, align='center', label='y')
ax2.grid(axis='both')
ax2.legend(loc='best')
ax2.set_title('Frequencies of $x$ and $y$')
ax2.set_ylabel('Frequency')
ax2.yaxis.tick_right()
ax2.set_xticks(np.arange(data.min(), data.max()+1))

# %%
from io import BytesIO
import tarfile
from urllib.request import urlopen

url = 'http://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.tgz'
b = BytesIO(urlopen(url).read())
fpath = 'CaliforniaHousing/cal_housing.data'
with tarfile.open(mode='r', fileobj=b) as archive:
    housing = np.loadtxt(archive.extractfile(fpath), delimiter=',')

def add_titlebox(ax_in, text_in):
    ax_in.text(.55, .8, text_in,
            horizontalalignment='center',
            transform=ax_in.transAxes,
            bbox=dict(facecolor='white', edgecolor='k', alpha=0.6),
            fontsize=12.5)
    return ax_in

gridsize = (3,2)
fig_new = plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid(gridsize, (0,0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2,0))
ax3 = plt.subplot2grid(gridsize, (2,1))

y = housing[:,-1]
pop, age = housing[:, [4, 7]].T

ax1.set_title('Home value as a function of home age and area population',
              fontsize=14)
sctr = ax1.scatter(x=age, y=pop, c =y, cmap='RdYlGn')
plt.colorbar(sctr, ax=ax1, format='$%d')
ax1.set_yscale('log')
ax2.hist(age, bins='auto')
ax2.set_xlim(xmin=0)
ax3.hist(pop, bins='auto', log=True)
ax3.set_xlim(xmin=0, xmax=max(pop))
add_titlebox(ax2, 'Histogram: home age')
add_titlebox(ax3, 'Histogram: area population')
# Out:
# <AxesSubplot: >

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

x = np.diag(np.arange(2, 12))[::-1]
x[np.diag_indices_from(x)] = np.arange(2,12)
x2 = np.arange(x.size).reshape(x.shape)
sides = ('left', 'right', 'top', 'bottom')
nolabels = {**{s: False for s in sides}, **{f'label{s}': False for s in sides}}
print(nolabels)

with plt.rc_context(rc={'axes.grid': False}):
    fig, axs = plt.subplots(1,2, figsize=(12, 8))
    im1 = axs[0].matshow(x)
    im2 = axs[1].matshow(x2, cmap="RdYlGn_r")
    for ax in axs:
        ax.tick_params(axis='both', which='both', **nolabels)
    for i, j in zip(*x.nonzero()):
        axs[0].text(j, i, x[i, j], color='white', ha='center', va='center', rotation=45)

divider = make_axes_locatable(axs[1])
cax = divider.append_axes("right", size='5%', pad='2%')
plt.colorbar(im2, cax=cax, ax=axs)

divider_left = make_axes_locatable(axs[0])
cax_t = divider_left.append_axes("top", size='5%', pad='2%')
plt.colorbar(im1, cax=cax_t, orientation='horizontal')
cax_t.xaxis.set_ticks_position("top")
# Out:
# {'left': False, 'right': False, 'top': False, 'bottom': False, 'labelleft': False, 'labelright': False, 'labeltop': False, 'labelbottom': False}

# %%
# See https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html for style reference
my_style = 'bmh'
#plt.style.use('ggplot')
plt.style.use(my_style)
s = pd.Series(np.random.randint(low=1, high=10, size=5), index=list('abcde'))
ax=s.plot(marker="*", ms=22, ls='-.')
ax.set_title(f"Using the '{my_style}' style")
ax.set_xlabel('Categories')
ax.set_ylabel('Random number')
# ax.set_ylim(ymin=0, ymax=s.max()+0.5)
# ax.set_xlim(xmin=-0.5, xmax=len(s)+0.5)
ax.margins(0.1)

type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
import matplotlib.transforms as mtransforms
import matplotlib.dates as mdates

url = 'https://fred.stlouisfed.org/graph/fredgraph.csv?id=VIXCLS'
vix = pd.read_csv(url, index_col=0, parse_dates=True, na_values='.',
                  infer_datetime_format=True,
                  ).squeeze("columns").dropna()
ma = vix.rolling('90d').mean()
state = pd.cut(ma, bins=[-np.inf, 14, 18, 24, np.inf], labels=range(4))

cmap = plt.get_cmap('RdYlGn_r')
vix.plot(color='gray', linewidth=1, linestyle=':',
         figsize=(12,6), label='VIX')
ma.plot(color='k', linewidth=1.5, label='VIX 90d MA')

ax = plt.gca()
ax.set_xlabel('Date')
ax.set_ylabel('CBOE VIX')
ax.set_title('Volatility Regime State')
ax.legend()
ax.set_xlim(xmin=ma.index[0], xmax=ma.index[-1])
ax.xaxis.set_major_locator(mdates.YearLocator(2))
ax.xaxis.set_minor_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# transforms between the axis data points (x and y values) and coordinate points of the axis
trans = mtransforms.blended_transform_factory(ax.transData, ax.transAxes)
for i, color in enumerate(cmap([0.2, 0.4, 0.6, 0.8])):
    ax.fill_between(ma.index, 0, 1, where=state==i,
                    facecolor=color, alpha=0.9, transform=trans)
ax.axhline(vix.mean(), linestyle='--', color="xkcd:slate", alpha=0.6,
           label = 'Full-period mean')

# %%
import matplotlib as mpl
from matplotlib.figure import Figure


CUSTOM_CMAP = mpl.colors.ListedColormap(['red', 'green', 'black', 'yellow', 'blue'])

random_data = np.random.randint(0, 5, size=(10,10))
fig, ax = plt.subplots()


ax.matshow(random_data, cmap = CUSTOM_CMAP)
ax.xaxis.set_ticks(np.arange(-0.5, 10.5, 1))
ax.yaxis.set_ticks(np.arange(-0.5, 9.5, 1))
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.grid(True, color="black", linewidth="3", linestyle="-")
